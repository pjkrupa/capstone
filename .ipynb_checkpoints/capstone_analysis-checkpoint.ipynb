# %%
import psycopg2, pprint, json
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
from analysis.functions import preprocess_failures, show_run_stats, show_failures, show_unique, sum_failures
from analysis.visualizations import plot_validation_rate, plot_failures

# %% [markdown]
# Helper functions:

# %%
def pivot_df(df, field):
    df_pivoted = (
        df.groupby([field], as_index=False)
          .agg(
              sample_size=("run_id", "size"),
              passed_validation=("passed_validation", "sum"),
              )
        )
    return df_pivoted

# %% [markdown]
# Fetch all the raw data from the database and load it into a dataframe:

# %%
engine = create_engine("postgresql+psycopg2://player:higgybig@hpmini/play_db")

query = "SELECT * FROM responses;"

df = pd.read_sql(query, 
                 engine,
                )

# %% [markdown]
# Now separate the data out into a Test A dataframe and a Test B dataframe:

# %%
df_a = df[df['run_id'] == 'test_a']
df_b = df[df['run_id'] == 'test_b']

# %% [markdown]
# Run some exploration functions to see what each set looks like, then trim df_a down to the model runs that interest us:

# %%
show_run_stats(df_a)
# Out:
# Run ID: test_a
# Models used: ['anthropic/claude-sonnet-4-20250514', 'ollama/deepseek-r1:8b', 'ollama/llama3.1:8b', 'ollama/llama3.3:70b', 'ollama/llama3:8b', 'ollama_chat/command-r-plus:104b', 'ollama_chat/gpt-oss:120b', 'ollama_chat/llama3.1:8b', 'ollama_chat/llama3.3:70b', 'openai/gpt-4o', 'openai/gpt-5-nano']
# Number of requests: 6850
# Estimated duration of the entire run: 27 days 05:53:41.672993
# Validated requests: 40.82%
# The run used 9,640,222 prompt tokens and 3,658,018 completion tokens.
# Estimated cost of the run: US$0

# %%
def graph_counts(df):
    run = df['run_id'].iloc[0]
    model_counts = df['model'].value_counts()

    plt.figure(figsize=(10, 6))
    plt.bar(model_counts.index, model_counts.values)
    plt.xlabel('Model')
    plt.ylabel('Sample')
    plt.title(f'Number of queries per model for {run}')
    plt.xticks(rotation=78)

    # Show the plot
    #plt.tight_layout()
    plt.show()

graph_counts(df_a)

# %% [markdown]
# ### Data Cleanup
# Here we are going to split off `ollama_chat/gpt-oss:120b`, `ollama_chat/command-r-plus:104b`, `ollama_chat/llama3.1:8b` into a separate `df_explore`, and then slim `df_a` down to only the model runs eligible for a `test_b` run:

# %%
df_explore = df_a[df_a['model'].isin(['ollama_chat/gpt-oss:120b', 'ollama_chat/command-r-plus:104b', 'ollama_chat/llama3.1:8b'])]

# %%
df_a = df_a[df_a['model'].isin(['anthropic/claude-sonnet-4-20250514', 
             'openai/gpt-4o', 
             'openai/gpt-5-nano', 
             'ollama/llama3.3:70b'])]

# %% [markdown]
# And now in `df_b` we are going to keep only the model runs that we will use for the "B" part of the A/B tests:

# %%
df_b = df_b[df_b['model'].isin(['anthropic/claude-sonnet-4-20250514', 'openai/gpt-4o', 'openai/gpt-5-nano'])]

# %% [markdown]
# Let's see how the models did. The percentage of queries validated corresponds to _p_.

# %%
df_a_analysis = pivot_df(df_a, 'model')
df_a_analysis['validation_rate'] = df_a_analysis['passed_validation'] / df_a_analysis['sample_size']
plot_validation_rate(df_a_analysis)

# %%
df_a_analysis.head()
# Out:
#                                 model  sample_size  passed_validation  \
# 0  anthropic/claude-sonnet-4-20250514         1000                245
# 1                 ollama/llama3.3:70b          999                893
# 2                       openai/gpt-4o         1000                835
# 3                   openai/gpt-5-nano         1000                823
#
#    validation_rate
# 0         0.245000
# 1         0.893894
# 2         0.835000
# 3         0.823000

# %% [markdown]
# So the probability that the models will return a response that successfully passes validation is:
# - `ollama/llama3.3:70b`: _p_ = 0.89
# - `openai/gpt-4o`: _p_ = 0.84
# - `openai/gpt-5-nano`: _p_ = 0.82
# - `anthropic/claude-sonnet-4-20250514`: _p_ = 0.24
#
# Now let's see what they got wrong:

# %%
# get a dataframe with just the failures
df_a_failures = preprocess_failures(df_a)

# hotswap encode them into their own fields
df_a_failures_analysis = sum_failures(df_a_failures)

# merge it with the pivoted analysis df
df_a_final = pd.merge(
    df_a_analysis,
    df_a_failures_analysis,
    on=['model'],
    how='inner'
)

# %%
plot_failures(df_a_final, 1750)

# %%
print(df_a_failures[df_a_failures['model'] == 'anthropic/claude-sonnet-4-20250514']['validation_errors'].iloc[10])
# Out:
# {'date_admitted': {'message': "'2050-07-01T00:00:00Z' is not one of ['2050-07-01T00:00:00']", 'validator': 'enum', 'validator_value': ['2050-07-01T00:00:00']}, 'date_discharged': {'message': "'2050-07-03T00:00:00Z' is not one of ['2050-07-03T00:00:00']", 'validator': 'enum', 'validator_value': ['2050-07-03T00:00:00']}}

# %% [markdown]
# Let's leave `ollama/llama3.3:70b` aside for the moment. It looks like the major problem the other three models are having is with the date format. Indeed, if we look at an example error from `anthropic/claude-sonnet-4-20250514`, we can see where the problem lies:
#
#     {'date_admitted': {'message': "'2050-07-01T00:00:00Z' is not one of ['2050-07-01T00:00:00']", 'validator': 'enum', 'validator_value': ['2050-07-01T00:00:00']}, 'date_discharged': {'message': "'2050-07-03T00:00:00Z' is not one of ['2050-07-03T00:00:00']", 'validator': 'enum', 'validator_value': ['2050-07-03T00:00:00']}}
#
# Sometimes, the model is adding a timezone value (Z for UTC), sometimes it is not. This was the error for the other models as well, and an example of the kind of stochasticity that poses a risk. The model essentially has a "choice," and with nothing to guide that choice, the result is open to chance.
#
# Let's see if we can improve the validation rate by tweaking our prompt.

# %%
df_b_analysis = pivot_df(df_b, 'model')
df_b_analysis['validation_rate'] = df_b_analysis['passed_validation'] / df_b_analysis['sample_size']
plot_validation_rate(df_b_analysis)

# %%
df_b_analysis.head()
# Out:
#                                 model  sample_size  passed_validation  \
# 0  anthropic/claude-sonnet-4-20250514         1000                995
# 1                       openai/gpt-4o         1000                991
# 2                   openai/gpt-5-nano         1000                924
#
#    validation_rate
# 0            0.995
# 1            0.991
# 2            0.924

# %% [markdown]
# Much better. Now our results look like the following:
#
# - `openai/gpt-4o`: _p_ = 0.991
# - `openai/gpt-5-nano`: _p_ = 0.924
# - `anthropic/claude-sonnet-4-20250514`: _p_ = 0.995

# %% [markdown]
# And let's take a look at what the failures look like:

# %%
# get a dataframe with just the failures
df_b_failures = preprocess_failures(df_b)

# hotswap encode them into their own fields
df_b_failures_analysis = sum_failures(df_b_failures)

# merge it with the pivoted analysis df
df_b_final = pd.merge(
    df_b_analysis,
    df_b_failures_analysis,
    on=['model'],
    how='inner'
)

# %%
plot_failures(df_b_final, 100)

# %%
df_a_b_stats = (
    df_a_final[['model', 'validation_rate', 'sample_size', 'passed_validation']]
    .merge(df_b_final[['model', 'validation_rate', 'sample_size', 'passed_validation']], on='model', suffixes=('_a', '_b'))
    .rename(columns={
        'validation_rate_a': 'p_a', 
        'validation_rate_b': 'p_b',
        'sample_size_a': 'n_a',
        'sample_size_b': 'n_b',
        'passed_validation_a': 'x_a',
        'passed_validation_b': 'x_b'
    }
           )
)
df_a_b_stats.head()
# Out:
#                                 model    p_a   n_a  x_a    p_b   n_b  x_b
# 0  anthropic/claude-sonnet-4-20250514  0.245  1000  245  0.995  1000  995
# 1                       openai/gpt-4o  0.835  1000  835  0.991  1000  991
# 2                   openai/gpt-5-nano  0.823  1000  823  0.924  1000  924

# %%
df_a_b_stats['diff'] = df_a_b_stats['p_b'] - df_a_b_stats['p_a']
df_a_b_stats['p_hat'] = (df_a_b_stats['x_a'] + df_a_b_stats['x_b']) / (df_a_b_stats['n_a'] + df_a_b_stats['n_b'])
df_a_b_stats['se'] = np.sqrt(df_a_b_stats['p_hat'] * (1-df_a_b_stats['p_hat']) * (1/df_a_b_stats['n_a']+1/df_a_b_stats['n_b']))
df_a_b_stats['z'] = df_a_b_stats['diff'] / df_a_b_stats['se']


df_a_b_stats.head()
# Out:
#                                 model    p_a   n_a  x_a    p_b   n_b  x_b  \
# 0  anthropic/claude-sonnet-4-20250514  0.245  1000  245  0.995  1000  995
# 1                       openai/gpt-4o  0.835  1000  835  0.991  1000  991
# 2                   openai/gpt-5-nano  0.823  1000  823  0.924  1000  924
#
#     diff   p_hat        se          z
# 0  0.750  0.6200  0.021707  34.550841
# 1  0.156  0.9130  0.012604  12.376977
# 2  0.101  0.8735  0.014866   6.794064

# %%
ordered_columns = [
    'model',
    'n_a',
    'x_a', 
    'p_a',
    'n_b',
    'x_b',
    'p_b',
    'diff',
    'p_hat',
    'se',
    'z'
]
df_a_b_stats = df_a_b_stats[ordered_columns]
df_a_b_stats.head()
# Out:
#                                 model   n_a  x_a    p_a   n_b  x_b    p_b  \
# 0  anthropic/claude-sonnet-4-20250514  1000  245  0.245  1000  995  0.995
# 1                       openai/gpt-4o  1000  835  0.835  1000  991  0.991
# 2                   openai/gpt-5-nano  1000  823  0.823  1000  924  0.924
#
#     diff   p_hat        se          z
# 0  0.750  0.6200  0.021707  34.550841
# 1  0.156  0.9130  0.012604  12.376977
# 2  0.101  0.8735  0.014866   6.794064

# %%
df_print = df_a_b_stats[['model', 'p_hat', 'se', 'z']]
df_print.head()
# Out:
#                                 model   p_hat        se          z
# 0  anthropic/claude-sonnet-4-20250514  0.6200  0.021707  34.550841
# 1                       openai/gpt-4o  0.9130  0.012604  12.376977
# 2                   openai/gpt-5-nano  0.8735  0.014866   6.794064

# %% [markdown]
# Next steps:
# - Calculate probabilities of `test_a` group validation
# - Explore error types
# - Make changes to query
# - Run `test_b` and A/B test probabilities
# - Run local model tests
# - Explore error types
# - Final observation: some stochastic errors (blood pressure) cannot be fixed with a query adjustment
